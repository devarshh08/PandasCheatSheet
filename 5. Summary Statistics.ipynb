# %% [markdown]
# Summary statistics

# %%
import pandas as pd
df = pd.read_csv("E:\CODING\GitHub Repositories\PandasCheatSheet\Churn_Modelling_Only_Nums.csv")

# %%
df.describe()
# Out:
#         RowNumber    CustomerId  CreditScore         Age      Tenure  \
# count  665.000000  6.650000e+02   665.000000  665.000000  665.000000
# mean   333.000000  1.569270e+07   648.177444   38.703759    5.129323
# std    192.113248  7.135363e+04   100.553896   10.169397    2.967413
# min      1.000000  1.556611e+07   376.000000   19.000000    0.000000
# 25%    167.000000  1.563005e+07   578.000000   32.000000    3.000000
# 50%    333.000000  1.569441e+07   653.000000   37.000000    5.000000
# 75%    499.000000  1.575205e+07   722.000000   44.000000    8.000000
# max    665.000000  1.581404e+07   850.000000   80.000000   10.000000
#
#              Balance  NumOfProducts   HasCrCard  IsActiveMember  \
# count     665.000000     665.000000  665.000000      665.000000
# mean    75554.902406       1.524812    0.723308        0.503759
# std     62742.129269       0.575400    0.447699        0.500362
# min         0.000000       1.000000    0.000000        0.000000
# ...

# %% [markdown]
# pandas-summary is a python package that provides a more elaborate summary statistics
#
# #pip install pandas-summary

# %%
from pandas_summary import DataFrameSummary
dfs = DataFrameSummary(df)

# %%
dfs.columns_stats
# Out:
#              RowNumber CustomerId CreditScore      Age   Tenure  Balance  \
# counts             665        665         665      665      665      665
# uniques            665        665         310       56       11      422
# missing              0          0           0        0        0        0
# missing_perc        0%         0%          0%       0%       0%       0%
# types          numeric    numeric     numeric  numeric  numeric  numeric
#
#              NumOfProducts HasCrCard IsActiveMember EstimatedSalary Exited
# counts                 665       665            665             665    665
# uniques                  4         2              2             665      2
# missing                  0         0              0               0      0
# missing_perc            0%        0%             0%              0%     0%
# types              numeric      bool           bool         numeric   bool

# %% [markdown]
# Categorical/String column

# %%
df2 = pd.read_csv("E:\CODING\GitHub Repositories\PandasCheatSheet\Churn_Modelling.csv")
df2['Geography'].describe()
#you can get information such as unique values, counts, etc
# Out:
# count      10000
# unique         3
# top       France
# freq        5014
# Name: Geography, dtype: object

# %% [markdown]
# Numeric column summary

# %%
df['EstimatedSalary'].describe()
# Out:
# count       665.000000
# mean     100218.007789
# std       57385.826830
# min         371.050000
# 25%       53134.300000
# 50%      100127.710000
# 75%      148210.640000
# max      199725.390000
# Name: EstimatedSalary, dtype: float64

# %% [markdown]
# Essential Operations

# %% [markdown]
# View unique items

# %%
df['Age'].unique()
# Out:
# array([42, 41, 39, 43, 44, 50, 29, 27, 31, 24, 34, 25, 35, 45, 58, 32, 38,
#        46, 36, 33, 40, 51, 61, 49, 37, 19, 66, 56, 26, 21, 55, 75, 22, 30,
#        28, 65, 48, 52, 57, 73, 47, 54, 72, 20, 67, 79, 62, 53, 80, 59, 68,
#        23, 60, 70, 63, 64], dtype=int64)

# %% [markdown]
# Number of unique items

# %%
df['Age'].nunique()
# Out:
# 56

# %% [markdown]
# Number of occurrences of each item

# %%
df2['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df2['Geography'].value_counts(normalize=True).head()

#In pandas, the normalize parameter is used to normalize the data. When set to True, it normalizes the data by dividing all values by the sum of values in the row or column depending on the value of the axis parameter. The default value of normalize is False.
#normalize gives the proportion of number of times each of these values occurred, sum of all the values should add upto 1. It is kinda like percentage.
# Out:
# Geography
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: proportion, dtype: float64

# %% [markdown]
# Get first 'n' rows order by a given column

# %%
df.nlargest(5, 'Age')
# Out:
#      RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 310        311    15712287          652   80       4       0.00
# 252        253    15793726          681   79       0       0.00
# 85          86    15805254          652   75      10       0.00
# 371        372    15774696          640   75       1  106307.91
# 158        159    15589975          646   73       6   97259.25
#
#      NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 310              2          1               1        188603.07       0
# 252              2          0               1        170968.99       0
# 85               2          1               1        114675.75       0
# 371              2          0               1        113428.77       0
# 158              1          0               1        104719.66       0

# %% [markdown]
# Drop a column
#
# use inplace = True

# %%
df2.drop(columns = 'Geography')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Gender  Age  Tenure  \
# 0             1    15634602   Hargrave          619  Female   42       2
# 1             2    15647311       Hill          608  Female   41       1
# 2             3    15619304       Onio          502  Female   42       8
# 3             4    15701354       Boni          699  Female   39       1
# 4             5    15737888   Mitchell          850  Female   43       2
# ...         ...         ...        ...          ...     ...  ...     ...
# 9995       9996    15606229   Obijiaku          771    Male   39       5
# 9996       9997    15569892  Johnstone          516    Male   35      10
# 9997       9998    15584532        Liu          709  Female   36       7
# 9998       9999    15682355  Sabbatini          772    Male   42       3
# 9999      10000    15628319     Walker          792  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df2.head()
#in df2 geography is present because we did not actually permanently drop the particular column.
#for permanent dropping we need to use inplace = True
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# Drop records by index

# %%
df.drop(index = [0, 1, 2])
# Out:
#      RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 3            4    15701354          699   39       1       0.00
# 4            5    15737888          850   43       2  125510.82
# 5            6    15574012          645   44       8  113755.78
# 6            7    15592531          822   50       7       0.00
# 7            8    15656148          376   29       4  115046.74
# ..         ...         ...          ...  ...     ...        ...
# 660        661    15592937          632   41       3   81877.38
# 661        662    15699637          694   57       8  116326.07
# 662        663    15667215          678   31       2       0.00
# 663        664    15788659          695   46       4       0.00
# 664        665    15763218          661   41       1       0.00
#
#      NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 3                2          0               0         93826.63       0
# ...

# %% [markdown]
# How to transpose a dataframe

# %%
df.T
# Out:
#                          0            1            2            3    \
# RowNumber               1.00         2.00         3.00         4.00
# CustomerId       15634602.00  15647311.00  15619304.00  15701354.00
# CreditScore           619.00       608.00       502.00       699.00
# Age                    42.00        41.00        42.00        39.00
# Tenure                  2.00         1.00         8.00         1.00
# Balance                 0.00     83807.86    159660.80         0.00
# NumOfProducts           1.00         1.00         3.00         2.00
# HasCrCard               1.00         0.00         1.00         0.00
# IsActiveMember          1.00         1.00         0.00         0.00
# EstimatedSalary    101348.88    112542.58    113931.57     93826.63
# Exited                  1.00         0.00         1.00         0.00
#
#                          4            5           6            7    \
# RowNumber               5.00         6.00         7.0         8.00
# ...

# %%
df.T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, RowNumber to Exited
# Columns: 665 entries, 0 to 664
# dtypes: float64(665)
# memory usage: 57.5+ KB

# %% [markdown]
# Since transposing will bring element of different datatypes in one column, all columns are converted to 'object' datatype
