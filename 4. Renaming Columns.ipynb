# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("E:\CODING\GitHub Repositories\PandasCheatSheet\Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Get column names

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# Rename columns

# %%
df.rename  (columns = {'NumOfProducts' : 'NumberOfProducts'}, inplace = True)
#if we dont use inplace = True columns will be unchanged
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumberOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# Rename all columns in one shot. Change case

# %%
df.rename(str.upper, axis = 'columns').head()
#Pandas head() method is used to return top n (5 by default) rows of a data frame or series.
# Out:
#    ROWNUMBER  CUSTOMERID   SURNAME  CREDITSCORE GEOGRAPHY  GENDER  AGE  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    TENURE    BALANCE  NUMBEROFPRODUCTS  HASCRCARD  ISACTIVEMEMBER  \
# 0       2       0.00                 1          1               1
# 1       1   83807.86                 1          0               1
# 2       8  159660.80                 3          1               0
# 3       1       0.00                 2          0               0
# 4       2  125510.82                 1          1               1
#
#    ESTIMATEDSALARY  EXITED
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# ...

# %% [markdown]
# Rename all columns in one shot : Replace all 'a' characters with "_"
#
# Use a lambda function

# %%
df.rename(lambda x: x.replace("a", "_"), axis = 'columns').head()
# Out:
#    RowNumber  CustomerId   Surn_me  CreditScore Geogr_phy  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    B_l_nce  NumberOfProducts  H_sCrC_rd  IsActiveMember  \
# 0       2       0.00                 1          1               1
# 1       1   83807.86                 1          0               1
# 2       8  159660.80                 3          1               0
# 3       1       0.00                 2          0               0
# 4       2  125510.82                 1          1               1
#
#    Estim_tedS_l_ry  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# ...
